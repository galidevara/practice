# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn import  datasets

# %%
houses=datasets.fetch_california_housing()

# %%
houses
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
# ...

# %%
hws=pd.DataFrame(houses.data,columns=houses.feature_names)
hws
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
tgt=pd.DataFrame(houses.target,columns=['value'])

# %%
data=hws.join(tgt)
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  value
# ...

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         value
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
from scipy.stats import zscore
dt=abs(zscore(data))
print(data.shape)
data_new=data.loc[(dt<3).all(axis=1)]
print(data_new.shape)
# Out:
# (20640, 9)
# (19794, 9)

# %%
sns.heatmap(data_new.corr())

# %%
data.skew()
# Out:
# MedInc         1.646657
# HouseAge       0.060331
# AveRooms      20.697869
# AveBedrms     31.316956
# Population     4.935858
# AveOccup      97.639561
# Latitude       0.465953
# Longitude     -0.297801
# value          0.977763
# dtype: float64

# %%
data_new.skew()
# Out:
# MedInc        0.786048
# HouseAge      0.046496
# AveRooms      0.555865
# AveBedrms     3.913734
# Population    1.346151
# AveOccup      5.789707
# Latitude      0.460162
# Longitude    -0.292814
# value         0.970197
# dtype: float64

# %%
for i in data_new.columns:
    if data_new.skew().loc[i]>0.50:
        data_new[i]=np.log(data_new[i])
        
print(data_new.skew())
# Out:
# MedInc       -0.365402
# HouseAge      0.046496
# AveRooms     -0.521171
# AveBedrms     2.057205
# Population   -1.308884
# AveOccup      0.401215
# Latitude      0.460162
# Longitude    -0.292814
# value        -0.191254
# dtype: float64

# %%
sns.pairplot(data_new)

# %%
x=data_new.drop(columns=['value'])
y=data_new['value']

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import r2_score,accuracy_score,confusion_matrix,classification_report

# %%
def max_r2(reg,x,y):
    maxsrc=0
    for r in range(45,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r)
        reg.fit(x_train,y_train)
        y_pred=reg.predict(x_test)
        r2src=r2_score(y_test,y_pred)
        if maxsrc<r2src:
            maxsrc=r2src
            final=r
            print("for final state",final,'max r2 score is:',maxsrc)    
    print('score of model:',reg.score(x_train,y_train))
    print('Cross val score:',cross_val_score(reg,x,y,cv=5).mean())

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
max_r2(lr,x,y)
# Out:
# for final state 45 max r2 score is: 0.6763210365640395
# for final state 48 max r2 score is: 0.6848444634885735
# score of model: 0.6713091455866127
# Cross val score: 0.582123351390879

# %%
from sklearn.tree import DecisionTreeRegressor
dct=DecisionTreeRegressor()
max_r2(dct,x,y)
# Out:
# for final state 45 max r2 score is: 0.6427208922387162
# for final state 46 max r2 score is: 0.661745042776188
# for final state 47 max r2 score is: 0.6690123681522773
# for final state 59 max r2 score is: 0.671373314166307
# for final state 68 max r2 score is: 0.6744340071279276
# for final state 74 max r2 score is: 0.6761954516399058
# for final state 80 max r2 score is: 0.6766401163818918
# for final state 85 max r2 score is: 0.6828772779253758
# score of model: 0.9999999985656677
# Cross val score: 0.323148200997434

# %%
from sklearn.neighbors import KNeighborsRegressor
kn=KNeighborsRegressor()
max_r2(kn,x,y)
# Out:
# for final state 45 max r2 score is: 0.7144856747832544
# for final state 56 max r2 score is: 0.7203304222915623
# score of model: 0.8101882417048756
# Cross val score: 0.4819922144590917

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
max_r2(rfr,x,y)
# Out:
# for final state 45 max r2 score is: 0.8135832374560277
# for final state 48 max r2 score is: 0.8143027918571976
# for final state 49 max r2 score is: 0.8150473114755701
# for final state 52 max r2 score is: 0.8176851347263266
# for final state 58 max r2 score is: 0.8178616787492516
# for final state 60 max r2 score is: 0.8187122756281355
# for final state 83 max r2 score is: 0.8232340463811414
# score of model: 0.9669988715488634
# Cross val score: 0.5914104163948048

# %%
from sklearn.ensemble import AdaBoostRegressor
adb=AdaBoostRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,50,100,1000]}
clf=GridSearchCV(adb,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 50}

# %%
adb=AdaBoostRegressor(learning_rate=0.1,n_estimators=50)
max_r2(adb,x,y)
# Out:
# for final state 45 max r2 score is: 0.5842254136255197
# for final state 56 max r2 score is: 0.5864285882307656
# for final state 58 max r2 score is: 0.5899505517311523
# for final state 77 max r2 score is: 0.5914646975493941
# score of model: 0.5911288326469379
# Cross val score: 0.44253192551021553

# %%
from sklearn.externals import joblib
joblib.dump(rfr,'Housing.pk1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['Housing.pk1']
