# %%
#1

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url=("https://en.wikipedia.org/wiki/Main_Page")
res=requests.get(url)
res
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(res.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
tags=soup.find_all('h2',{"class":"mp-h2"})
tags
# Out:
# [<h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>,
#  <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>,
#  <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>,
#  <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>,
# ...

# %%
headers=''
for i in tags:
    headers=headers+ '      '+i.text
print(headers)
# Out:
#       From today's featured article      Did you know ...      In the news      On this day      Today's featured picture      Other areas of Wikipedia      Wikipedia's sister projects      Wikipedia languages

# %%
#2

# %%
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html')

movies = soup.select('td.titleColumn')
cast = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]

imdb = []

for index in range(0, 100):
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    data = {"movie_title": movie_title,
            "star_cast": cast[index],
            "rating": ratings[index]}
    imdb.append(data)
IMDB=pd.DataFrame(imdb)
IMDB
# Out:
#                  movie_title  \
# 0   The Shawshank Redemption
# 1              The Godfather
# 2     The Godfather: Part II
# 3            The Dark Knight
# 4               12 Angry Men
# ..                       ...
# 95                    Jagten
# 96              Citizen Kane
# 97                      1917
# 98         Full Metal Jacket
# 99       Ladri di biciclette
#
#                                             star_cast             rating
# 0   Frank Darabont (dir.), Tim Robbins, Morgan Fre...   9.22279289095073
# 1   Francis Ford Coppola (dir.), Marlon Brando, Al...   9.14868491755109
# 2   Francis Ford Coppola (dir.), Al Pacino, Robert...  8.980951158537051
# 3   Christopher Nolan (dir.), Christian Bale, Heat...  8.973513264437683
# 4       Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb  8.930835413790078
# ..                                                ...                ...
# 95  Thomas Vinterberg (dir.), Mads Mikkelsen, Thom...   8.25802313768129
# ...

# %%
#4

# %%
url2=("https://bookpage.com/reviews")

response = requests.get(url2)

# %%
Book_name=[]
Author=[]
Review=[]
soup=BeautifulSoup(response.text,'html.parser')
count=0
for a in soup.find_all('div',{"class":"flex-article-content"}):
    if count<5:
        book_name=a.find('h4',{"class":"italic"})
        author_name=a.find('p',{"class":"sans bold"})
        review=a.find('p',{"class":"excerpt"})
        Book_name.append(book_name.text)
        Author.append(author_name.text)
        Review.append(review.text)
        count=+1

# %%
import pandas as pd
df = pd.DataFrame({'Book_name':Book_name,'Author':Author,'Review':Review})

# %%
#5

# %%
url3=("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
response = requests.get(url3)
soup = BeautifulSoup(response.content)
teams = soup.find_all("table")
df = pd.read_html(str(teams))[0]
df=df.head(10)

# %%
df
# Out:
#    Pos           Team T  Matches M  Points P  Rating R
# 0    1      England ENG         44      5405       123
# 1    2        India IND         49      5819       119
# 2    3   New Zealand NZ         32      3716       116
# 3    4    Australia AUS         36      3941       109
# 4    5  South Africa SA         31      3345       108

# %%
url4=("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
response = requests.get(url4)
soup = BeautifulSoup(response.content)
batsmen = soup.find_all("table")
bt = pd.read_html(str(batsmen))[0]
bt=bt.head(10)

# %%
bt
# Out:
#   Pos               Player Team  Rating            Career Best Rating
# 0   1          Virat Kohli  IND     871     911 v England, 12/07/2018
# 1   2         Rohit Sharma  IND     855   885 v Sri Lanka, 06/07/2019
# 2   3           Babar Azam  PAK     829   846 v Sri Lanka, 20/10/2017
# 3   4          Ross Taylor   NZ     818  841 v Bangladesh, 05/06/2019
# 4   5  Francois du Plessis   SA     790   820 v Australia, 06/07/2019

# %%
url5=("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
response = requests.get(url5)
soup = BeautifulSoup(response.content)
bowlers = soup.find_all("table")
bw = pd.read_html(str(bowlers))[0]
bw=bw.head(10)

# %%
bw
# Out:
#                                                  Pos            Player Team  \
# 0                                                  1       Trent Boult   NZ
# 1                                                  2    Jasprit Bumrah  IND
# 2                                                  3  Mujeeb Ur Rahman  AFG
# 3  4  This player has moved up in the rankings si...      Chris Woakes  ENG
# 4                                                  5     Kagiso Rabada   SA
# 5  6  This player has moved up in the rankings si...       Pat Cummins  AUS
# 6  7  This player has moved up in the rankings si...     Mohammad Amir  PAK
# 7  8  This player has moved down in the rankings ...    Josh Hazlewood  AUS
# 8  9  This player has moved up in the rankings si...        Matt Henry   NZ
# 9  10  This player has moved down in the rankings...      Jofra Archer  ENG
#
#    Rating             Career Best Rating
# 0     722  770 v West Indies, 22/06/2019
# 1     719  841 v West Indies, 01/11/2018
# ...
