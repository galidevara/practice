# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
adult=pd.read_csv('Adult.csv',names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation',
                                      'relationship','race','sex','capital-gain','capital-loss','hours-per-week',
                                      'native-country','income'])
adult
# Out:
#       age          workclass  fnlwgt      education  education-num  \
# 0      39          State-gov   77516      Bachelors             13
# 1      50   Self-emp-not-inc   83311      Bachelors             13
# 2      38            Private  215646        HS-grad              9
# 3      53            Private  234721           11th              7
# 4      28            Private  338409      Bachelors             13
# ...   ...                ...     ...            ...            ...
# 3402   66                  ?  190324        HS-grad              9
# 3403   26            Private   31350           11th              7
# 3404   41            Private  243607        5th-6th              3
# 3405   47          Local-gov  134671   Some-college             10
# 3406   31            Private  197023      Assoc-voc             11
#
#            marital-status          occupation    relationship  \
# 0           Never-married        Adm-clerical   Not-in-family
# ...

# %%
adult['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
adult['income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
adt=adult.replace(to_replace=' ?',value=np.nan)
adt
# Out:
#       age          workclass  fnlwgt      education  education-num  \
# 0      39          State-gov   77516      Bachelors             13
# 1      50   Self-emp-not-inc   83311      Bachelors             13
# 2      38            Private  215646        HS-grad              9
# 3      53            Private  234721           11th              7
# 4      28            Private  338409      Bachelors             13
# ...   ...                ...     ...            ...            ...
# 3402   66                NaN  190324        HS-grad              9
# 3403   26            Private   31350           11th              7
# 3404   41            Private  243607        5th-6th              3
# 3405   47          Local-gov  134671   Some-college             10
# 3406   31            Private  197023      Assoc-voc             11
#
#            marital-status          occupation    relationship  \
# 0           Never-married        Adm-clerical   Not-in-family
# ...

# %%
adt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3407 entries, 0 to 3406
# Data columns (total 15 columns):
# age               3407 non-null int64
# workclass         3190 non-null object
# fnlwgt            3407 non-null int64
# education         3407 non-null object
# education-num     3407 non-null int64
# marital-status    3407 non-null object
# occupation        3190 non-null object
# relationship      3407 non-null object
# race              3407 non-null object
# sex               3407 non-null object
# capital-gain      3407 non-null int64
# capital-loss      3407 non-null int64
# hours-per-week    3407 non-null int64
# native-country    3339 non-null object
# income            3407 non-null object
# dtypes: int64(6), object(9)
# memory usage: 399.4+ KB

# %%
adt.isnull().sum()
# Out:
# age                 0
# workclass         217
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        217
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country     68
# income              0
# dtype: int64

# %%
adt['workclass'].mode()
# Out:
# 0     Private
# dtype: object

# %%
adt.dropna(inplace=True)

# %%
print(adt['workclass'].unique())
print(adt['occupation'].unique())
print(adt['native-country'].unique())
# Out:
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' Self-emp-inc' ' Without-pay']
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Transport-moving' ' Farming-fishing'
#  ' Machine-op-inspct' ' Tech-support' ' Craft-repair' ' Protective-serv'
#  ' Armed-Forces' ' Priv-house-serv']
# [' United-States' ' Cuba' ' Jamaica' ' India' ' Mexico' ' Puerto-Rico'
#  ' Honduras' ' England' ' Canada' ' Germany' ' Iran' ' Philippines'
#  ' Poland' ' Columbia' ' Cambodia' ' Thailand' ' Ecuador' ' Laos'
#  ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic' ' El-Salvador'
#  ' France' ' Guatemala' ' Italy' ' China' ' South' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland']

# %%
adt.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
adt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3128 entries, 0 to 3406
# Data columns (total 15 columns):
# age               3128 non-null int64
# workclass         3128 non-null object
# fnlwgt            3128 non-null int64
# education         3128 non-null object
# education-num     3128 non-null int64
# marital-status    3128 non-null object
# occupation        3128 non-null object
# relationship      3128 non-null object
# race              3128 non-null object
# sex               3128 non-null object
# capital-gain      3128 non-null int64
# capital-loss      3128 non-null int64
# hours-per-week    3128 non-null int64
# native-country    3128 non-null object
# income            3128 non-null object
# dtypes: int64(6), object(9)
# memory usage: 391.0+ KB

# %%
adt.describe()
# Out:
#                age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  3128.000000  3.128000e+03    3128.000000   3128.000000   3128.000000
# mean     38.766944  1.909228e+05      10.152174   1093.244885     98.444373
# std      12.985110  1.057309e+05       2.542102   7498.486891    423.735940
# min      17.000000  1.930200e+04       1.000000      0.000000      0.000000
# 25%      28.000000  1.177890e+05       9.000000      0.000000      0.000000
# 50%      38.000000  1.800560e+05      10.000000      0.000000      0.000000
# 75%      47.000000  2.417720e+05      13.000000      0.000000      0.000000
# max      90.000000  1.033222e+06      16.000000  99999.000000   2547.000000
#
#        hours-per-week
# count     3128.000000
# mean        41.323529
# std         11.554553
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adt.plot(kind='box',layout=(2,8),subplots=True)
# Out:
# age                  AxesSubplot(0.125,0.536818;0.0824468x0.343182)
# fnlwgt            AxesSubplot(0.223936,0.536818;0.0824468x0.343182)
# education-num     AxesSubplot(0.322872,0.536818;0.0824468x0.343182)
# capital-gain      AxesSubplot(0.421809,0.536818;0.0824468x0.343182)
# capital-loss      AxesSubplot(0.520745,0.536818;0.0824468x0.343182)
# hours-per-week    AxesSubplot(0.619681,0.536818;0.0824468x0.343182)
# dtype: object

# %%
sns.heatmap(adt.corr())

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %% [raw]
# workclass, education, marital-status, occupation, relationship, race, sex, native-country, income

# %%
adt['workclass']=le.fit_transform(adt['workclass'])
adt['education']=le.fit_transform(adt['education'])
adt['marital-status']=le.fit_transform(adt['marital-status'])
adt['occupation']=le.fit_transform(adt['occupation'])
adt['relationship']=le.fit_transform(adt['relationship'])
adt['race']=le.fit_transform(adt['race'])
adt['sex']=le.fit_transform(adt['sex'])
adt['native-country']=le.fit_transform(adt['native-country'])
adt['income']=le.fit_transform(adt['income'])

# %%
adt['income'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
adt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3128 entries, 0 to 3406
# Data columns (total 15 columns):
# age               3128 non-null int64
# workclass         3128 non-null int32
# fnlwgt            3128 non-null int64
# education         3128 non-null int32
# education-num     3128 non-null int64
# marital-status    3128 non-null int32
# occupation        3128 non-null int32
# relationship      3128 non-null int32
# race              3128 non-null int32
# sex               3128 non-null int32
# capital-gain      3128 non-null int64
# capital-loss      3128 non-null int64
# hours-per-week    3128 non-null int64
# native-country    3128 non-null int32
# income            3128 non-null int32
# dtypes: int32(9), int64(6)
# memory usage: 281.0 KB

# %%
adt.describe()
# Out:
#                age    workclass        fnlwgt    education  education-num  \
# count  3128.000000  3128.000000  3.128000e+03  3128.000000    3128.000000
# mean     38.766944     2.206202  1.909228e+05    10.303069      10.152174
# std      12.985110     0.953341  1.057309e+05     3.820262       2.542102
# min      17.000000     0.000000  1.930200e+04     0.000000       1.000000
# 25%      28.000000     2.000000  1.177890e+05     9.000000       9.000000
# 50%      38.000000     2.000000  1.800560e+05    11.000000      10.000000
# 75%      47.000000     2.000000  2.417720e+05    12.000000      13.000000
# max      90.000000     6.000000  1.033222e+06    15.000000      16.000000
#
#        marital-status   occupation  relationship         race          sex  \
# count     3128.000000  3128.000000   3128.000000  3128.000000  3128.000000
# mean         2.590793     6.019821      1.434783     3.677110     0.682545
# std          1.514477     4.052137      1.620217     0.826078     0.465561
# ...

# %%
sns.heatmap(adt.corr())

# %%
sns.pairplot(adt)

# %%
adt.skew()
# Out:
# age                0.522702
# workclass          1.156532
# fnlwgt             1.220365
# education         -0.961888
# education-num     -0.291491
# marital-status     0.023132
# occupation         0.090711
# relationship       0.826696
# race              -2.446418
# sex               -0.784695
# capital-gain      11.904735
# capital-loss       4.173676
# hours-per-week     0.199287
# native-country    -4.091000
# income             1.110600
# dtype: float64

# %%
from scipy.stats import zscore
dt=abs(zscore(adt))
print(adt.shape)
adt_new=adt.loc[(dt<3).all(axis=1)]
print(adt_new.shape)
# Out:
# (3128, 15)
# (2678, 15)

# %%
adt_new.skew()
# Out:
# age                0.442521
# workclass          1.189115
# fnlwgt             0.605146
# education         -0.993880
# education-num     -0.127017
# marital-status    -0.011447
# occupation         0.080974
# relationship       0.807428
# race              -2.516121
# sex               -0.750140
# capital-gain       4.736926
# capital-loss      24.447535
# hours-per-week    -0.182261
# native-country    -5.126127
# income             1.215178
# dtype: float64

# %%
for i in adt_new.columns:
    if adt_new.skew().loc[i]>0.50:
        adt_new[i]=np.sqrt(adt_new[i])
        
print(adt_new.skew())
# Out:
# age                0.442521
# workclass         -1.162839
# fnlwgt            -0.128377
# education         -0.993880
# education-num     -0.127017
# marital-status    -0.011447
# occupation         0.080974
# relationship       0.152935
# race              -2.516121
# sex               -0.750140
# capital-gain       3.599577
# capital-loss      23.575110
# hours-per-week    -0.182261
# native-country    -5.126127
# income             1.215178
# dtype: float64

# %%
sns.distplot(adt_new['fnlwgt'])

# %%
x=adt_new.drop(columns=['income'])
y=adt_new['income']

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import r2_score,accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import roc_curve,roc_auc_score

# %%
def max_r2(reg,x,y):
    maxsrc=0
    for r in range(45,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r)
        reg.fit(x_train,y_train)
        ypred=reg.predict(x_test)
        r2src=r2_score(y_test,ypred)
        if maxsrc<r2src:
            maxsrc=r2src
            final=r
            print("for final state",final,'max r2 score is:',maxsrc)
    print('score of the model:',reg.score(x_train,y_train))
    print('accuracy of the model:',accuracy_score(y_test,ypred))
    print('Confussion matrix:',confusion_matrix(y_test,ypred))
    print('Clasification report:',classification_report(y_test,ypred))
    
    
    print('Cross val score:',cross_val_score(reg,x,y,cv=5).mean())
    print('auc_score is :',roc_auc_score(y_test,reg.predict(x_test)))

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
max_r2(lg,x,y)
# Out:
# for final state 45 max r2 score is: 0.039260284810126556
# for final state 48 max r2 score is: 0.12073490813648291
# score of the model: 0.8207171314741036
# accuracy of the model: 0.8149253731343283
# Confussion matrix: [[471  31]
#  [ 93  75]]
# Clasification report:               precision    recall  f1-score   support
#
#          0.0       0.84      0.94      0.88       502
#          1.0       0.71      0.45      0.55       168
#
#     accuracy                           0.81       670
#    macro avg       0.77      0.69      0.72       670
# weighted avg       0.80      0.81      0.80       670
#
# Cross val score: 0.8155486611884399
# auc_score is : 0.6923377916903813

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
dct=DecisionTreeClassifier()
parameters={'criterion':['gini','entropy']}
clf=GridSearchCV(dct,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'criterion': 'gini'}

# %%
dct=DecisionTreeClassifier('gini')
max_r2(dct,x,y)
# Out:
# score of the model: 1.0
# accuracy of the model: 0.7880597014925373
# Confussion matrix: [[434  68]
#  [ 74  94]]
# Clasification report:               precision    recall  f1-score   support
#
#          0.0       0.85      0.86      0.86       502
#          1.0       0.58      0.56      0.57       168
#
#     accuracy                           0.79       670
#    macro avg       0.72      0.71      0.71       670
# weighted avg       0.79      0.79      0.79       670
#
# Cross val score: 0.7752110235340154
# auc_score is : 0.7120328210965661

# %%
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier()
max_r2(kn,x,y)
# Out:
# score of the model: 0.8421314741035857
# accuracy of the model: 0.7611940298507462
# Confussion matrix: [[453  49]
#  [111  57]]
# Clasification report:               precision    recall  f1-score   support
#
#          0.0       0.80      0.90      0.85       502
#          1.0       0.54      0.34      0.42       168
#
#     accuracy                           0.76       670
#    macro avg       0.67      0.62      0.63       670
# weighted avg       0.74      0.76      0.74       670
#
# Cross val score: 0.7830524344569288
# auc_score is : 0.6208380762663631

# %%
from sklearn.svm import SVC
svc=SVC()
max_r2(svc,x,y)
# Out:
# score of the model: 0.99800796812749
# accuracy of the model: 0.7492537313432835
# Confussion matrix: [[501   1]
#  [167   1]]
# Clasification report:               precision    recall  f1-score   support
#
#          0.0       0.75      1.00      0.86       502
#          1.0       0.50      0.01      0.01       168
#
#     accuracy                           0.75       670
#    macro avg       0.62      0.50      0.43       670
# weighted avg       0.69      0.75      0.64       670
#
# Cross val score: 0.7602688803175135
# auc_score is : 0.5019801745399355

# %%
from sklearn.ensemble import RandomForestClassifier
rfr=RandomForestClassifier()
max_r2(rfr,x,y)
# Out:
# for final state 45 max r2 score is: 0.08895371835443033
# for final state 48 max r2 score is: 0.13701759502284427
# for final state 59 max r2 score is: 0.15361941584044703
# for final state 85 max r2 score is: 0.1542892156862743
# for final state 95 max r2 score is: 0.17378106621134504
# score of the model: 0.9815737051792829
# accuracy of the model: 0.8149253731343283
# Confussion matrix: [[462  40]
#  [ 84  84]]
# Clasification report:               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.88       502
#          1.0       0.68      0.50      0.58       168
#
#     accuracy                           0.81       670
#    macro avg       0.76      0.71      0.73       670
# weighted avg       0.80      0.81      0.80       670
#
# Cross val score: 0.830093912460171
# auc_score is : 0.7101593625498007

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

# %%
gbr=GradientBoostingClassifier()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,50,100,1000]}
clf=GridSearchCV(gbr,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
gbr=GradientBoostingClassifier(learning_rate=0.01,n_estimators=1000)
max_r2(gbr,x,y)
# Out:
# for final state 45 max r2 score is: 0.27116297468354433
# score of the model: 0.8889442231075697
# accuracy of the model: 0.8373134328358209
# Confussion matrix: [[467  35]
#  [ 74  94]]
# Clasification report:               precision    recall  f1-score   support
#
#          0.0       0.86      0.93      0.90       502
#          1.0       0.73      0.56      0.63       168
#
#     accuracy                           0.84       670
#    macro avg       0.80      0.74      0.76       670
# weighted avg       0.83      0.84      0.83       670
#
# Cross val score: 0.8450332606629771
# auc_score is : 0.7449013469929805

# %%
adb=AdaBoostClassifier()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,50,100,1000]}
clf=GridSearchCV(adb,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
adb=AdaBoostClassifier(learning_rate=0.1,n_estimators=1000)
max_r2(adb,x,y)
# Out:
# for final state 45 max r2 score is: 0.26288073575949367
# for final state 59 max r2 score is: 0.2733095994589697
# score of the model: 0.8675298804780877
# accuracy of the model: 0.8343283582089552
# Confussion matrix: [[469  33]
#  [ 78  90]]
# Clasification report:               precision    recall  f1-score   support
#
#          0.0       0.86      0.93      0.89       502
#          1.0       0.73      0.54      0.62       168
#
#     accuracy                           0.83       670
#    macro avg       0.79      0.73      0.76       670
# weighted avg       0.83      0.83      0.83       670
#
# Cross val score: 0.8465271954832578
# auc_score is : 0.7349886169607285

# %%
    from sklearn.externals import joblib
joblib.dump(gbr,'Census.pk1')
# Out:
# ['Census.pk1']
