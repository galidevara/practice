# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
hrt=pd.read_csv('heart.csv',names=['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang'
                                  ,'oldpeak','slope','ca','thal','num'])
hrt
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
hrt=hrt.replace(to_replace='?',value=np.nan)

# %%
hrt.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
data=hrt.dropna()
data
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
data['num'].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
data.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
print(data['ca'].unique())
print(data['thal'].unique())
# Out:
# [0. 3. 2. 1.]
# ['6.0' '3.0' '7.0']

# %%
data['ca']=data['ca'].astype(float)
data['thal']=data['thal'].astype(float)

# %%
data['num'].dtype
# Out:
# dtype('int64')

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    3.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    1.602694    0.676768
# ...

# %%
sns.heatmap(data.corr())

# %%
data.plot(kind='box',layout=(2,7),subplots=True)
# Out:
# age            AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# sex         AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# cp          AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# trestbps    AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# chol        AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# fbs         AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# restecg     AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# thalach           AxesSubplot(0.125,0.125;0.0945122x0.343182)
# exang          AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# oldpeak        AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# slope          AxesSubplot(0.465244,0.125;0.0945122x0.343182)
# ca             AxesSubplot(0.578659,0.125;0.0945122x0.343182)
# thal           AxesSubplot(0.692073,0.125;0.0945122x0.343182)
# num            AxesSubplot(0.805488,0.125;0.0945122x0.343182)
# dtype: object

# %%
data.skew()
# Out:
# age        -0.219775
# sex        -0.759727
# cp         -0.844412
# trestbps    0.700070
# chol        1.118096
# fbs         2.029240
# restecg     0.006768
# thalach    -0.536540
# exang       0.743256
# oldpeak     1.247131
# slope       0.510444
# ca          1.179548
# thal        0.247772
# num         1.046557
# dtype: float64

# %%
from scipy.stats import zscore
dt=abs(zscore(data))
print(data.shape)
data_new=data.loc[(dt<3).all(axis=1)]
data_new.shape
# Out:
# (297, 14)
# (288, 14)

# %%
data_new
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang   oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  0.0      2.0    150.0   -inf  1.516575
# 1    67.0  1.0  4.0     160.0  286.0 -inf      2.0    108.0    0.0  1.224745
# 2    67.0  1.0  4.0     120.0  229.0 -inf      2.0    129.0    0.0  1.612452
# 3    37.0  1.0  3.0     130.0  250.0 -inf      0.0    187.0   -inf  1.870829
# 4    41.0  0.0  2.0     130.0  204.0 -inf      2.0    172.0   -inf  1.183216
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...       ...
# 297  57.0  0.0  4.0     140.0  241.0 -inf      0.0    123.0    0.0  0.447214
# 298  45.0  1.0  1.0     110.0  264.0 -inf      0.0    132.0   -inf  1.095445
# 299  68.0  1.0  4.0     144.0  193.0  0.0      0.0    141.0   -inf  1.843909
# 300  57.0  1.0  4.0     130.0  131.0 -inf      0.0    115.0    0.0  1.095445
# 301  57.0  0.0  2.0     130.0  236.0 -inf      2.0    174.0   -inf  0.000000
#
#      slope        ca  thal       num
# ...

# %%
import numpy as np
for i in data_new.columns:
    if data_new.skew().loc[i]>0.55:
        data_new[i]=np.sqrt(data_new[i])

# %%
for i in data_new.columns:
    if data_new.skew().loc[i]>0.55:
        data_new[i]=np.log(data_new[i])

# %%
data_new.skew()
# Out:
# age        -0.189956
# sex        -0.813282
# cp         -0.827158
# trestbps    0.522019
# chol        0.237990
# fbs              NaN
# restecg     0.041891
# thalach    -0.478853
# exang            NaN
# oldpeak     0.094976
# slope       0.509286
# ca               NaN
# thal        0.291421
# num         0.516084
# dtype: float64

# %%
x=data_new.drop(columns=['fbs','exang','ca','num'])
y=data_new[['num']]
y=y.astype(int)
print(x.shape)
print(y.shape)
# Out:
# (288, 10)
# (288, 1)

# %%
from sklearn.metrics import r2_score,accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import cross_val_score,train_test_split
def max_r2score(reg,x,y):
    maxr2=0
    for r_state in range(45,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        reg.fit(x_train,y_train)
        y_pred=reg.predict(x_test)
        r2scr=r2_score(y_test,y_pred)
        if r2scr>maxr2:
            maxr2=r2scr
            final=r_state
            print('for the randon state:',final,'max r2scr is',maxr2)
    print(cross_val_score(reg,x,y,cv=5).mean())
    print(lg.score(x_train,y_train))
    print(accuracy_score(y_test,y_pred))
    print(confusion_matrix(y_test,y_pred))
    print(classification_report(y_test,y_pred))

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
max_r2score(lg,x,y)
# Out:
# for the randon state: 45 max r2scr is 0.43248532289628183
# for the randon state: 49 max r2scr is 0.45397489539748936
# for the randon state: 52 max r2scr is 0.5135135135135135
# for the randon state: 62 max r2scr is 0.5996932515337423
# 0.7707961092093178
# 0.7913043478260869
# 0.7758620689655172
# [[19  4  0]
#  [ 6 26  0]
#  [ 1  2  0]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.78        23
#            1       0.81      0.81      0.81        32
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.78        58
#    macro avg       0.51      0.55      0.53        58
# weighted avg       0.74      0.78      0.76        58

# %%
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier()
max_r2score(kn,x,y)
# Out:
# for the randon state: 65 max r2scr is 0.007941356139279043
# 0.6186983384820907
# 0.7913043478260869
# 0.5172413793103449
# [[18  5  0]
#  [20 12  0]
#  [ 2  1  0]]
#               precision    recall  f1-score   support
#
#            0       0.45      0.78      0.57        23
#            1       0.67      0.38      0.48        32
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.52        58
#    macro avg       0.37      0.39      0.35        58
# weighted avg       0.55      0.52      0.49        58

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
max_r2score(dtc,x,y)
# Out:
# for the randon state: 45 max r2scr is 0.16764514024788002
# for the randon state: 84 max r2scr is 0.2866603595080417
# 0.6346747933539284
# 0.7913043478260869
# 0.5689655172413793
# [[17  5  1]
#  [14 16  2]
#  [ 1  2  0]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.74      0.62        23
#            1       0.70      0.50      0.58        32
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.57        58
#    macro avg       0.41      0.41      0.40        58
# weighted avg       0.59      0.57      0.57        58

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
max_r2score(gnb,x,y)
# Out:
# for the randon state: 45 max r2scr is 0.5081539465101109
# 0.6642711029473157
# 0.7913043478260869
# 0.46551724137931033
# [[18  2  3]
#  [ 6  8 18]
#  [ 1  1  1]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75        23
#            1       0.73      0.25      0.37        32
#            2       0.05      0.33      0.08         3
#
#     accuracy                           0.47        58
#    macro avg       0.50      0.46      0.40        58
# weighted avg       0.69      0.47      0.51        58

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
grb=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[50,500,1000,1500]}
clf=GridSearchCV(grb,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'learning_rate': 0.001, 'n_estimators': 1500}

# %%
maxr2=0
for r_state in range(45,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state)
    grb=GradientBoostingRegressor(learning_rate=0.001,n_estimators=1500)
    grb.fit(x_train,y_train)
    y_pred=grb.predict(x_test)
    r2scr=r2_score(y_test,y_pred)
    if r2scr>maxr2:
        maxr2=r2scr
        final=r_state
        print('for the randon state:',final,'max r2scr is',maxr2)
print(cross_val_score(grb,x,y,cv=10).mean())
# Out:
# for the randon state: 45 max r2scr is 0.2696522599677962
# for the randon state: 46 max r2scr is 0.32508320588758743
# for the randon state: 48 max r2scr is 0.34705384678480466
# for the randon state: 49 max r2scr is 0.4321879879251118
# for the randon state: 55 max r2scr is 0.43945554361951755
# for the randon state: 70 max r2scr is 0.4531537185267951
# 0.36819918722690065

# %%
from sklearn.ensemble import AdaBoostRegressor
adb=AdaBoostRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[50,500,1000,1500]}
clf=GridSearchCV(adb,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'learning_rate': 0.001, 'n_estimators': 1500}

# %%
 maxr2=0
for r_state in range(45,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state)
    adb=AdaBoostRegressor(learning_rate=0.001,n_estimators=1500)
    adb.fit(x_train,y_train)
    y_pred=adb.predict(x_test)
    r2scr=r2_score(y_test,y_pred)
    if r2scr>maxr2:
        maxr2=r2scr
        final=r_state
        print('for the randon state:',final,'max r2scr is',maxr2)
print(cross_val_score(adb,x,y,cv=10).mean())
# Out:
# for the randon state: 45 max r2scr is 0.3477385620137541
# for the randon state: 48 max r2scr is 0.3529615582186162
# for the randon state: 49 max r2scr is 0.4540956451016238
# for the randon state: 62 max r2scr is 0.48033464400923276
# for the randon state: 66 max r2scr is 0.4913291871754051
# for the randon state: 80 max r2scr is 0.4994134162687047
# 0.4005737752494697

# %%
from sklearn.externals import joblib
joblib.dump(lg,'HeartDisease.pk1')
