# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
bball=pd.read_csv('Base_Ball.csv')
bball
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
bball.describe()
# Out:
#                 R           AB            H          2B         3B  \
# count   30.000000    30.000000    30.000000   30.000000  30.000000
# mean   688.233333  5516.266667  1403.533333  274.733333  31.300000
# std     58.761754    70.467372    57.140923   18.095405  10.452355
# min    573.000000  5385.000000  1324.000000  236.000000  13.000000
# 25%    651.250000  5464.000000  1363.000000  262.250000  23.000000
# 50%    689.000000  5510.000000  1382.500000  275.500000  31.000000
# 75%    718.250000  5570.000000  1451.500000  288.750000  39.000000
# max    891.000000  5649.000000  1515.000000  308.000000  49.000000
#
#                HR          BB          SO          SB          RA          ER  \
# count   30.000000   30.000000    30.00000   30.000000   30.000000   30.000000
# mean   163.633333  469.100000  1248.20000   83.500000  688.233333  635.833333
# std     31.823309   57.053725   103.75947   22.815225   72.108005   70.140786
# ...

# %%
bball.isnull().sum()
# Out:
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# W      0
# dtype: int64

# %%
sns.heatmap(bball.corr())

# %%
bball.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# W      0.047089
# dtype: float64

# %%
bball.plot(kind='box',layout=(2,9),subplots=True)

# %%
sns.pairplot(bball)

# %%
from scipy.stats import zscore
dt=abs(zscore(bball))
print(bball.shape)
bball_new=bball.loc[(dt<3).all(axis=1)]
print(bball_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
bball_new.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# W      0.119013
# dtype: float64

# %%
for i in bball_new.columns:
    if bball_new.skew().loc[i]>0.50:
        bball_new[i]=np.log(bball_new[i])

# %%
bball_new.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.738423
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG          NaN
# SHO   -0.726124
# SV     0.096752
# E      0.583308
# W      0.119013
# dtype: float64

# %%
sns.heatmap(bball_new.corr())

# %%
x=columns=bball_new.drop(columns=['W','CG','H'])
y=bball_new[['W']]
print(x.shape)
print(y.shape)
# Out:
# (29, 14)
# (29, 1)

# %%
from math import sqrt
maxrscr=0
for r in range(45,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    ypred=lr.predict(x_test)
    rscr=r2_score(y_test,ypred)
    if rscr>maxrscr:
        maxrscr=rscr
    final=r
print('for the randon state:',final,'max r2scr is',maxrscr)
print(lr.score(x_train,y_train))

from sklearn.model_selection import cross_val_score
print(cross_val_score(lr,x,y,cv=5).mean())
# Out:
# for the randon state: 99 max r2scr is 0.8810376137069023
# 0.9308064967562508
# 0.07648904789643471

# %%
maxrscr=0
for r in range(45,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r)
    dtc=DecisionTreeRegressor()
    dtc.fit(x_train,y_train)
    ypred=dtc.predict(x_test)
    rscr=r2_score(y_test,ypred)
    if rscr>maxrscr:
        maxrscr=rscr
    final=r
print('for the randon state:',final,'max r2scr is',maxrscr)
print(dtc.score(x_train,y_train))

from sklearn.model_selection import cross_val_score
print(cross_val_score(dtc,x,y,cv=5).mean())
# Out:
# for the randon state: 99 max r2scr is 0.7145866245392312
# 1.0
# -2.570121780715739

# %%
maxrscr=0
for r in range(45,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r)
    kn=KNeighborsRegressor()
    kn.fit(x_train,y_train)
    ypred=kn.predict(x_test)
    rscr=r2_score(y_test,ypred)
    if rscr>maxrscr:
        maxrscr=rscr
    final=r
print('for the randon state:',final,'max r2scr is',maxrscr)
print(kn.score(x_train,y_train))

from sklearn.model_selection import cross_val_score
print(cross_val_score(kn,x,y,cv=5).mean())
# Out:
# for the randon state: 99 max r2scr is 0.7720447609359107
# 0.3982239634345416
# -0.3713747420468805

# %%
def maxscore(reg,x,y):
    max_score=0
    for r in range (45,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r,test_size=0.20)
        reg.fit(x_train,y_train)
        y_pred=reg.predict(x_test)
        r2scr=r2_score(y_test,y_pred)
        if r2scr>max_score:
            max_score=r2scr
            final=r
    print("max_r2score for",final,'is',max_score)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.001, 'n_estimators': 100}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.001,n_estimators=100)
r=maxscore(gbr,x,y)
print('cors_val_score mean:',cross_val_score(gbr,x,y,cv=5,scoring='r2').mean())
print('cors_val_score std:',cross_val_score(gbr,x,y,cv=5).std())
# Out:
# max_r2score for 46 is 0.13819998076538442
# cors_val_score mean: -0.34104198546032516
# cors_val_score std: 0.35607432243965514

# %%
from sklearn.ensemble import AdaBoostRegressor

adb=AdaBoostRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
clf=GridSearchCV(adb,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.001, 'n_estimators': 100}

# %%
adb=AdaBoostRegressor(learning_rate=0.001,n_estimators=100)
r=maxscore(adb,x,y)
print('cors_val_score mean:',cross_val_score(adb,x,y,cv=5).mean())
print('cors_val_score std:',cross_val_score(adb,x,y,cv=5).std())
# Out:
# max_r2score for 48 is 0.8178796218086701
# cors_val_score mean: -1.275108615370686
# cors_val_score std: 2.3284439967370667

# %%
from sklearn.externals import joblib
joblib.dump(lr,'Baseball.pk1')
